# %%
#extract text from corpus
#tokenization
#pos_tagging
#identifying stems

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import gutenberg

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
len(gutenberg.fileids())
# Out:
# 18

# %%
txt = gutenberg.words('carroll-alice.txt')

# %%
len(txt)
# Out:
# 34110

# %%
txt
# Out:
# ['[', 'Alice', "'", 's', 'Adventures', 'in', ...]

# %%
ps = PorterStemmer()

for text in txt:
 sentences = nltk.sent_tokenize(text)
 for sentence in sentences:
        words= nltk.word_tokenize(sentence) 
 words=[ps.stem(word) for word in words]
 print(words)
 tagged= nltk.pos_tag(words)
 print(tagged)
# Out:
# ['[']
# [('[', 'NN')]
# ['alic']
# [('alic', 'NN')]
# ["'"]
# [("'", "''")]
# ['s']
# [('s', 'NN')]
# ['adventur']
# [('adventur', 'NN')]
# ['in']
# [('in', 'IN')]
# ['wonderland']
# [('wonderland', 'NN')]
# ['by']
# [('by', 'IN')]
# ['lewi']
# [('lewi', 'NN')]
# ['carrol']
# [('carrol', 'NN')]
# ['1865']
# [('1865', 'CD')]
# [']']
# [(']', 'NN')]
# ['chapter']
# [('chapter', 'NN')]
# ['I']
# [('I', 'PRP')]
# ['.']
# [('.', '.')]
# ['down']
# [('down', 'RB')]
# ['the']
# [('the', 'DT')]
# ['rabbit']
# [('rabbit', 'NN')]
# ['-']
# [('-', ':')]
# ['hole']
# [('hole', 'NN')]
# ['alic']
# [('alic', 'NN')]
# ['wa']
# [('wa', 'NN')]
# ['begin']
# [('begin', 'NN')]
# ['to']
# [('to', 'TO')]
# ['get']
# [('get', 'VB')]
# ['veri']
# [('veri', 'NN')]
# ['tire']
# [('tire', 'NN')]
# ['of']
# [('of', 'IN')]
# ['sit']
# [('sit', 'NN')]
# ['by']
# [('by', 'IN')]
# ['her']
# [('her', 'PRP$')]
# ['sister']
# [('sister', 'NN')]
# ['on']
# [('on', 'IN')]
# ['the']
# [('the', 'DT')]
# ['bank']
# ...

# %%
from nltk import FreqDist
fdist = FreqDist(txt)

# %%
fdist.most_common(50)
# Out:
# [(',', 1993),
#  ("'", 1731),
#  ('the', 1527),
#  ('and', 802),
#  ('.', 764),
#  ('to', 725),
#  ('a', 615),
#  ('I', 543),
#  ('it', 527),
#  ('she', 509),
#  ('of', 500),
#  ('said', 456),
#  (",'", 397),
#  ('Alice', 396),
#  ('in', 357),
#  ('was', 352),
#  ('you', 345),
#  ("!'", 278),
#  ('that', 275),
#  ('as', 246),
#  ('her', 243),
#  (':', 216),
#  ('t', 216),
#  ('at', 202),
#  ('s', 195),
#  ('on', 189),
#  (".'", 187),
#  (';', 186),
#  ('had', 177),
#  ('with', 175),
#  ('all', 173),
#  ('!', 155),
#  ("?'", 154),
#  ('be', 145),
#  ('-', 141),
#  ('for', 140),
#  ('--', 140),
#  ('but', 133),
#  ('not', 129),
#  ('they', 129),
#  ('very', 126),
#  ('little', 125),
#  ('so', 124),
#  ('out', 116),
#  ('this', 113),
#  ('The', 108),
#  ('he', 101),
#  ('down', 99),
#  ('up', 98),
#  ('is', 97)]

# %%
from nltk.probability import ConditionalFreqDist
list=ConditionalFreqDist()

# %%
out=ConditionalFreqDist((len(word),word) for word in txt)

# %%
out[10]
# Out:
# FreqDist({'everything': 12, 'frightened': 7, 'understand': 6, 'melancholy': 6, 'dreadfully': 6, 'altogether': 5, 'remembered': 5, 'procession': 5, 'particular': 4, 'difficulty': 4, ...})

# %%
from nltk.tokenize import sent_tokenize
concat=" ".join(txt)
token=sent_tokenize(concat)
print(token)
# Out:
# ["[ Alice ' s Adventures in Wonderland by Lewis Carroll 1865 ] CHAPTER I .", "Down the Rabbit - Hole Alice was beginning to get very tired of sitting by her sister on the bank , and of having nothing to do : once or twice she had peeped into the book her sister was reading , but it had no pictures or conversations in it , ' and what is the use of a book ,' thought Alice ' without pictures or conversation ?'", 'So she was considering in her own mind ( as well as she could , for the hot day made her feel very sleepy and stupid ), whether the pleasure of making a daisy - chain would be worth the trouble of getting up and picking the daisies , when suddenly a White Rabbit with pink eyes ran close by her .', "There was nothing so VERY remarkable in that ; nor did Alice think it so VERY much out of the way to hear the Rabbit say to itself , ' Oh dear !", 'Oh dear !', "I shall be late !'", '( when she thought it over afterwards , it occurred to her that she ought to have wondered at this , 
# ...

# %%
tagged = nltk.pos_tag(concat)
print(tagged)
# Out:
# [('[', 'NN'), (' ', 'VBZ'), ('A', 'NNP'), ('l', 'NN'), ('i', 'NN'), ('c', 'VBP'), ('e', 'NN'), (' ', 'NNP'), ("'", 'POS'), (' ', 'NN'), ('s', 'NN'), (' ', 'VBZ'), ('A', 'NNP'), ('d', 'NN'), ('v', 'NN'), ('e', 'NN'), ('n', 'JJ'), ('t', 'NN'), ('u', 'JJ'), ('r', 'NN'), ('e', 'NN'), ('s', 'VBD'), (' ', 'NNP'), ('i', 'NN'), ('n', 'VBP'), (' ', 'JJ'), ('W', 'NNP'), ('o', 'NN'), ('n', 'NN'), ('d', 'NN'), ('e', 'NN'), ('r', 'NN'), ('l', 'VBZ'), ('a', 'DT'), ('n', 'JJ'), ('d', 'NN'), (' ', 'NN'), ('b', 'NN'), ('y', 'NN'), (' ', 'NNP'), ('L', 'NNP'), ('e', 'VBP'), ('w', 'NN'), ('i', 'NN'), ('s', 'VBP'), (' ', 'NNP'), ('C', 'NNP'), ('a', 'DT'), ('r', 'NN'), ('r', 'NN'), ('o', 'NN'), ('l', 'NN'), ('l', 'NN'), (' ', 'VBD'), ('1', 'CD'), ('8', 'CD'), ('6', 'CD'), ('5', 'CD'), (' ', 'NN'), (']', 'NNP'), (' ', 'NNP'), ('C', 'NNP'), ('H', 'NNP'), ('A', 'NNP'), ('P', 'NNP'), ('T', 'NNP'), ('E', 'NNP'), ('R', 'NNP'), (' ', 'NNP'), ('I', 'PRP'), (' ', 'VBP'), ('.', '.'), (' ', 'JJ'), ('D', 'NNP'), ('o'
# ...

# %%
stemmer = PorterStemmer()
print("Previous\n:",concat)

concat = [stemmer.stem(token) for token in concat.split(" ")]
print("New:")
print(" ".join(concat))
# Out:
# Previous
# ...
