# %%
#frequency checking

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.corpus import gutenberg

# %%
gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
len(gutenberg.fileids())
# Out:
# 18

# %%
text_sample = gutenberg.words('austen-sense.txt')

# %%
len(text_sample)
# Out:
# 141576

# %%
text_sample
# Out:
# ['[', 'Sense', 'and', 'Sensibility', 'by', 'Jane', ...]

# %%
sample = []
for words in text_sample:
    if len(words)>3:
        sample.append(words)

# %%
from nltk import FreqDist
fdist = FreqDist(text_sample)
fdist
# Out:
# FreqDist({',': 9397, 'to': 4063, '.': 3975, 'the': 3861, 'of': 3565, 'and': 3350, 'her': 2436, 'a': 2043, 'I': 2004, 'in': 1904, ...})

# %%
new_fd = sorted(fdist.items(), key = lambda x:x[1])

# %%
print(new_fd)
# Out:
# [('Sense', 1), ('Sensibility', 1), ('Jane', 1), ('Austen', 1), ('1811', 1), (']', 1), ('generations', 1), ('inheritor', 1), ('bequeath', 1), ('Gentleman', 1), ('relish', 1), ('devolved', 1), ('inheriting', 1), ('moiety', 1), ('bequest', 1), ('sale', 1), ('articulation', 1), ('economically', 1), ('tardy', 1), ('survived', 1), ('including', 1), ('legacies', 1), ('urgency', 1), ('prudently', 1), ('caricature', 1), ('warmed', 1), ('Three', 1), ('successively', 1), ('funeral', 1), ('dispute', 1), ('decease', 1), ('indelicacy', 1), ('keen', 1), ('whomsoever', 1), ('immoveable', 1), ('acutely', 1), ('qualified', 1), ('counsellor', 1), ('joys', 1), ('afflicted', 1), ('strive', 1), ('humored', 1), ('imbibed', 1), ('romance', 1), ('thirteen', 1), ('2', 1), ('installed', 1), ('degraded', 1), ('seasons', 1), ('alloy', 1), ('impoverishing', 1), ('headed', 1), ('stipulate', 1), ('LET', 1), ('diminished', 1), ('REALLY', 1), ('strikes', 1), ('Fifteen', 1), ('healthy', 1), ('clogged', 1), ('superannu
# ...

# %%
common_fd= list(new_fd) [len(new_fd)-1]

# %%
common_fd
# Out:
# (',', 9397)
